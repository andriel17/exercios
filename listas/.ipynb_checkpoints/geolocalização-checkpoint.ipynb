# %%
import folium 

latitude = -30.0346
longitude = -51.2177

mapa = folium.Map (location=[latitude,longitude], zoom_star=4)

folium.Marker([latitude, longitude], popup='Porto Alegre, RS, Brasil').add_to(mapa)

latitude = -23.5505
longitude = -46.6333

folium.Marker([latitude, longitude], popup='São Paulo, SP, Brasil').add_to(mapa)

latitude = -22.9068
longitude = -43.1729

folium.Marker([latitude, longitude], popup='Rio de Janeiro, RJ, Brasil').add_to(mapa)

latitude = -25.4290
longitude = -49.2671

folium.Marker([latitude, longitude], popup='Curitiba, PR, Brasil').add_to(mapa)

latitude = -19.9173
longitude = -43.9345

folium.Marker([latitude, longitude], popup='Belo Horizonte, SC, Brasil').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f3f79f7668ad6ff21983b42f6572ef2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f3f79f7668ad6ff21983b42f6572ef2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f3f79f7668ad6ff21983b42f6572ef2 = L.map(
#                 &quot;map_7f3f79f7668ad6ff21983b42f6572ef2&quot;,
#                 {
#                     center: [-30.0346, -51.2177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zoomStar: 4,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_898d98d0992662f24fb0eba80d021e5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_898d98d0992662f24fb0eba80d021e5b.addTo(map_7f3f79f7668ad6ff21983b42f6572ef2);
#
#
#             var marker_fe78698343bc26286afcaf13386fbfc1 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_7f3f79f7668ad6ff21983b42f6572ef2);
#
#
#         var popup_b9b567bc58040b06474026db9350fe14 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_067d30298698a5d4bdde01a1326d79b9 = $(`&lt;div id=&quot;html_067d30298698a5d4bdde01a1326d79b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_b9b567bc58040b06474026db9350fe14.setContent(html_067d30298698a5d4bdde01a1326d79b9);
#
#
#
#         marker_fe78698343bc26286afcaf13386fbfc1.bindPopup(popup_b9b567bc58040b06474026db9350fe14)
#         ;
#
#
#
#
#             var marker_88b883354ac1587e2fde30e762126671 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_7f3f79f7668ad6ff21983b42f6572ef2);
#
#
#         var popup_924c557fd88dab7b81db004c71d4c99d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa190f0521c304878dea6c6e8d74bf52 = $(`&lt;div id=&quot;html_aa190f0521c304878dea6c6e8d74bf52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_924c557fd88dab7b81db004c71d4c99d.setContent(html_aa190f0521c304878dea6c6e8d74bf52);
#
#
#
#         marker_88b883354ac1587e2fde30e762126671.bindPopup(popup_924c557fd88dab7b81db004c71d4c99d)
#         ;
#
#
#
#
#             var marker_56b74afe7277519f8aa168a0e9a09f6a = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_7f3f79f7668ad6ff21983b42f6572ef2);
#
#
#         var popup_e1c3a3f5550c2c71bde7ebc337ef1a51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1778ac8e81a34c713a5109c992bbb753 = $(`&lt;div id=&quot;html_1778ac8e81a34c713a5109c992bbb753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_e1c3a3f5550c2c71bde7ebc337ef1a51.setContent(html_1778ac8e81a34c713a5109c992bbb753);
#
#
#
#         marker_56b74afe7277519f8aa168a0e9a09f6a.bindPopup(popup_e1c3a3f5550c2c71bde7ebc337ef1a51)
#         ;
#
#
#
#
#             var marker_00b0b6a7cdfc17bfbf76d25b551b7905 = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_7f3f79f7668ad6ff21983b42f6572ef2);
#
#
#         var popup_7e124a41c75da736469180b3fd8049d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_244f9ebf673441fdc74fe84d2923845f = $(`&lt;div id=&quot;html_244f9ebf673441fdc74fe84d2923845f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_7e124a41c75da736469180b3fd8049d8.setContent(html_244f9ebf673441fdc74fe84d2923845f);
#
#
#
#         marker_00b0b6a7cdfc17bfbf76d25b551b7905.bindPopup(popup_7e124a41c75da736469180b3fd8049d8)
#         ;
#
#
#
#
#             var marker_272bf1a278db1f29daa2b99566464bc7 = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_7f3f79f7668ad6ff21983b42f6572ef2);
#
#
#         var popup_8ee5ac750b0596a7e2cbfca99b3e8d3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd522eb80dad3329a38fa4b01bc2c1cd = $(`&lt;div id=&quot;html_dd522eb80dad3329a38fa4b01bc2c1cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, SC, Brasil&lt;/div&gt;`)[0];
#                 popup_8ee5ac750b0596a7e2cbfca99b3e8d3c.setContent(html_dd522eb80dad3329a38fa4b01bc2c1cd);
#
#
#
#         marker_272bf1a278db1f29daa2b99566464bc7.bindPopup(popup_8ee5ac750b0596a7e2cbfca99b3e8d3c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" a
